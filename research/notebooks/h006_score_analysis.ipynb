# %% [markdown]
# # H-006 Score Analysis
#
# Measurement question: do pre-entry scores and packet features predict realized trade quality?
#
# Do not use this notebook to change production rules directly. Promote findings through the Strategy Registry and an Experiment Manifest.

# %% [markdown]
# ## Planned Inputs
#
# - `data/journal/decision_packets/`
# - `research/prospective_validation_log.csv`
#
# Key fields: score bucket, market score, sector score, confirmation score, distance to long strike, expected move, IV rank, RSI, relative strength, decision type, and future outcomes.
