# %% [markdown]
# # Semiconductor Review
#
# Review semiconductor evidence after H-005 rejection.
#
# Focus on structurally different hypotheses, not incremental retuning of the rejected high-beta profile.
